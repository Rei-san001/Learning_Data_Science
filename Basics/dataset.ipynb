# %% [markdown]
# # 1. Hello World

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # 2. Data Type

# %%
type('hello world')
# Out:
# str

# %%
"hello world".count('l')
# Out:
# 3

# %%
"hello world".replace('o', 'u')
# Out:
# 'hellu wurld'

# %%
1 + 2
# Out:
# 3

# %%
"Hello World!".count('l')
# Out:
# 3

# %% [markdown]
# # 3. Variables

# %%
msg = "It's fun"
msg2 = "ArithmeticError"

# %%
msg
# Out:
# "It's fun"

# %%
msg2
# Out:
# 'ArithmeticError'

# %%
msg + ' ' + msg2
# Out:
# "It's fun ArithmeticError"

# %%
f'hello there'
# Out:
# 'hello there'

# %%
f'{msg} and {msg2}'
# Out:
# "It's fun and ArithmeticError"

# %% [markdown]
# # 4. LIST

# %%
countries = ['USA', 'Canada', 'Mexico', 'Germany', 'France', 'Italy', 'Spain', 'Portugal', 'Netherlands', 'Belgium']

# %%
countries
# Out:
# ['USA',
#  'Canada',
#  'Mexico',
#  'Germany',
#  'France',
#  'Italy',
#  'Spain',
#  'Portugal',
#  'Netherlands',
#  'Belgium']

# %%
print(countries[9])
# Out:
# Belgium

# %%
countries[-1]
# Out:
# 'Belgium'

# %%
# slicing 
# list_name[start_index:end_index]

# %%
countries[0:3]
# Out:
# ['USA', 'Canada', 'Mexico']

# %%
countries[1:10]
# Out:
# ['Canada',
#  'Mexico',
#  'Germany',
#  'France',
#  'Italy',
#  'Spain',
#  'Portugal',
#  'Netherlands',
#  'Belgium']

# %%
countries[1:]
# Out:
# ['Canada',
#  'Mexico',
#  'Germany',
#  'France',
#  'Italy',
#  'Spain',
#  'Portugal',
#  'Netherlands',
#  'Belgium']

# %%
countries[:2]
# Out:
# ['USA', 'Canada']

# %% [markdown]
# ### 4.0.1 Adding elements to a LIST

# %%
countries
# Out:
# ['USA',
#  'Canada',
#  'Mexico',
#  'Germany',
#  'France',
#  'Italy',
#  'Spain',
#  'Portugal',
#  'Netherlands',
#  'Belgium']

# %%
countries.append('Sweden')

# %%
countries.insert(0, 'Norway')

# %%
countries[0]
# Out:
# 'Norway'

# %%
countries_2 = ['Finland', 'Denmark', 'Iceland']

# %%
countries + countries_2
# Out:
# ['Norway',
#  'Norway',
#  'USA',
#  'Canada',
#  'Mexico',
#  'Germany',
#  'France',
#  'Italy',
#  'Spain',
#  'Portugal',
#  'Netherlands',
#  'Belgium',
#  'Sweden',
#  'Sweden',
#  'Finland',
#  'Denmark',
#  'Iceland']

# %%
nested_list = [countries, countries_2]

# %%
nested_list
# Out:
# [['Norway',
#   'Norway',
#   'USA',
#   'Canada',
#   'Mexico',
#   'Germany',
#   'France',
#   'Italy',
#   'Spain',
#   'Portugal',
#   'Netherlands',
#   'Belgium',
#   'Sweden',
#   'Sweden'],
#  ['Finland', 'Denmark', 'Iceland']]

# %% [markdown]
# ### 4.0.2 Removing elements

# %%
countries = ['USA', 'Canada', 'Mexico', 'Germany', 'France']

# %%
countries.remove('USA')

# %%
countries[0]
# Out:
# 'Canada'

# %%
del countries[0]

# %%
countries
# Out:
# ['Germany', 'France']

# %%
countries.pop(-1)
# Out:
# 'France'

# %%
countries
# Out:
# ['USA', 'Canada', 'Mexico', 'Germany']

# %% [markdown]
# ### 4.0.3 Sorting a list

# %%
numbers = [4, 5, 6, 7, 8, 9]

# %%
numbers.sort()

# %%
numbers
# Out:
# [4, 5, 6, 7, 8, 9]

# %%
numbers = [4, 5, 6, 7, 8, 9]
numbers.sort(reverse=True)

# %%
numbers
# Out:
# [9, 8, 7, 6, 5, 4]

# %% [markdown]
# ### 4.0.4 update an element

# %%
numbers[0] = 1000
numbers
# Out:
# [1000, 8, 7, 6, 5, 4]

# %% [markdown]
# ### 4.0.5 Copying a list

# %%
countries = ['USA', 'Canada', 'Mexico', 'Germany', 'France']
new_list = countries[:]

# %%
new_list
# Out:
# ['USA', 'Canada', 'Mexico', 'Germany', 'France']

# %%
new_list_2 = countries.copy()

# %%
new_list_2
# Out:
# ['USA', 'Canada', 'Mexico', 'Germany', 'France']

# %% [markdown]
# # 5. Dictionary

# %%
my_dict = {
    'key1':'value1', 
    'key2':'value2'
    }

# %%
my_data = {'name':'Rei', 'age':25}

# %%
my_data
# Out:
# {'name': 'Rei', 'age': 25}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Rei', 25])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Rei'), ('age', 25)])

# %%
my_data['height'] = 1.7

# %%
my_data
# Out:
# {'name': 'Rei', 'age': 25, 'height': 1.7}

# %%
my_data.update({'height':1.95})  #to update the value of an existing key

# %%
my_data
# Out:
# {'name': 'Rei', 'age': 25, 'height': 1.95}

# %% [markdown]
# ### Copy a dictionary

# %%
new_dict = my_data.copy()   #does not change if the original dictionary is changed

# %%
new_dict
# Out:
# {'name': 'Rei', 'age': 25, 'height': 1.8}

# %%
new_dict_2 = my_data    #this method of copying will change if the original dictionary is changed

# %%
new_dict_2
# Out:
# {'name': 'Rei', 'age': 25, 'height': 1.95}

# %% [markdown]
# ### 5.0.2 Remove element

# %%
my_data.pop('name')
# Out:
# 'Rei'

# %%
my_data
# Out:
# {'age': 25, 'height': 1.95}

# %%
del my_data['age']

# %%
my_data
# Out:
# {'height': 1.95}

# %%
my_data.clear()

# %%
my_data
# Out:
# {}

# %% [markdown]
# # 6. If Statement

# %%
age = 13

if age>= 18:
    print("You are an adult")

elif age>=13:
    print("You are a teenager")

else:
    print("You are a minor")
# Out:
# You are a teenager

# %% [markdown]
# ### 7. For Loops

# %%
countries
# Out:
# ['USA', 'Canada', 'Mexico', 'Germany']

# %%
for country in countries:
    print(country)
# Out:
# USA
# Canada
# Mexico
# Germany

# %%
for i, country in enumerate(countries):
    print(i)
    print(country)
# Out:
# 0
# USA
# 1
# Canada
# 2
# Mexico
# 3
# Germany

# %%
my_data = {'name': 'rei', 'age': 24}
my_data
# Out:
# {'name': 'rei', 'age': 24}

# %%
for key, value in my_data.items():
    print(key)
    print(value)
# Out:
# name
# rei
# age
# 24

# %%
for key, value in my_data.items():
    print(f"{key}: {value}")
# Out:
# name: rei
# age: 24

# %% [markdown]
# # 8. Function

# %%
def sum_values(a, b):
    x = a + b
    return x

# %%
sum_values(5, 5)
# Out:
# 10

# %% [markdown]
# ### 8.1 Built-in Functions

# %%
countries = ['USA', 'Canada', 'Mexico', 'Germany', 'France']

# %%
len(countries)
# Out:
# 5

# %%
max([10, 63, 81, 1, 99])
# Out:
# 99

# %%
min([10, 63, 81, 1, 99])
# Out:
# 1

# %%
type(countries)
# Out:
# list

# %%
# 1 means start, 10 means end, 2 means step
for i in range(1, 10, 2): 
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# # 9. Modules

# %% [markdown]
# import

# %% [markdown]
# ### 9.1 OS Module

# %%
import os

# %%
os.getcwd() #cwd means current working directory. It returns the current working directory of a process.
# Out:
# 'd:\\JUPYTER_NOTEBOOK'

# %%
os.listdir()
# Out:
# ['.vscode', 'dataset.ipynb', 'first_notebook.ipynb']

# %%
os.makedirs('Test Folder')   #to create a new folder

# %%
os.listdir()
# Out:
# ['dataset.ipynb', 'Test Folder']
