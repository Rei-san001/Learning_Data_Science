# %%
import pandas as pd

# %%
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # 1. Adding a new column

# %% [markdown]
# ### 1.1 assign()

# %% [markdown]
# When to use assign() ?
#
#     > Add multiple columns in a single line of codes
#     > When you need to overwrite the values of an existing columns (best practice)
#
# -> It returns a new object (a copy) with all the original columns in addition to the new ones

# %%
import numpy as np

# %%
# create random numbers for our new score columns 
score1 = np.random.randint(1, 100, size=1000)
score2 = np.random.randint(1, 100, size=1000)

# %%
# create a series using the random numbers 
series1 = pd.Series(score1, index=np.arange(0,1000))
series2 = pd.Series(score2, index=np.arange(0,1000))

# %%
series1
# Out:
# 0       4
# 1      71
# 2      57
# 3      11
# 4      84
#        ..
# 995    86
# 996     1
# 997    58
# 998    68
# 999    15
# Length: 1000, dtype: int32

# %%
# using assign() to add multiple columns 
# we have to overwrite the df_exam to see the changes everywhere 
df_exams = df_exams.assign(score1=series1, score2=series2)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74       4
# 1                 completed          69             90             88      71
# 2                      none          90             95             93      57
# 3                      none          47             57             44      11
# 4                      none          76             78             75      84
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      86
# 996                    none          62             55             55       1
# 997               completed          59             71             65      58
# 998               completed          68             78             77      68
# 999                    none          77             86             86      15
#
#      score2
# 0        97
# 1        29
# 2        58
# 3        25
# 4        80
# ..      ...
# 995      32
# 996      80
# 997      83
# 998      51
# 999      78
#
# [1000 rows x 10 columns]

# %% [markdown]
# ### 1.2 insert()
#
#     > inserts a new column at a specific position or index

# %%
# using index() to add column at a specific position

df_exams.insert(1, 'test', series1)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female     4        group B           bachelor's degree      standard
# 1    female    71        group C                some college      standard
# 2    female    57        group B             master's degree      standard
# 3      male    11        group A          associate's degree  free/reduced
# 4      male    84        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    86        group E             master's degree      standard
# 996    male     1        group C                 high school  free/reduced
# 997  female    58        group C                 high school  free/reduced
# 998  female    68        group D                some college      standard
# 999  female    15        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74       4
# 1                 completed          69             90             88      71
# 2                      none          90             95             93      57
# 3                      none          47             57             44      11
# 4                      none          76             78             75      84
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      86
# 996                    none          62             55             55       1
# 997               completed          59             71             65      58
# 998               completed          68             78             77      68
# 999                    none          77             86             86      15
#
#      score2
# 0        97
# 1        29
# 2        58
# 3        25
# 4        80
# ..      ...
# 995      32
# 996      80
# 997      83
# 998      51
# 999      78
#
# [1000 rows x 11 columns]
